# %%
import pandas as pd
import numpy as np
import datetime
from datetime import datetime as dt
from pytz import country_timezones, timezone

#pip install timezonefinder
#pip install geopy

from geopy.geocoders import Nominatim
from timezonefinder import TimezoneFinder

print ('imported')
# Out:
# imported

# %%
geolocator = Nominatim(user_agent="geoapiExercises")
my_func = TimezoneFinder().timezone_at

# %%
task = pd.read_excel('Task_ Shah.xlsx')
task
# Out:
#                       Country              City  \
# 0         Antigua and Barbuda           Osbourn
# 1                   Argentina      Buenos Aires
# 2                       Aruba        Oranjestad
# 3                   Australia          Brisbane
# 4                   Australia            Cairns
# ...                       ...               ...
# 1066  United States (Wyoming)            Casper
# 1067  United States (Wyoming)              Cody
# 1068  United States (Wyoming)      Jackson Hole
# 1069                Venezuela           Caracas
# 1070                  Vietnam  Ho Chi Minh City
#
#                                      Airport name Airport code (IATA)  \
# 0                V. C. Bird International Airport                 ANU
# 1        Ministro Pistarini International Airport                 EZE
# 2             Queen Beatrix International Airport                 AUA
# 3                                Brisbane Airport                 BNE
# 4                                  Cairns Airport                 CNS
# ...                                           ...                 ...
# 1066  Casper-Natrona County International Airport                 CPR
# 1067                 Yellowstone Regional Airport                 COD
# 1068                         Jackson Hole Airport                 JAC
# 1069          Simon Bolivar International Airport                 CCS
# 1070           Tan Son Nhat International Airport                 SGN
#
#       Airport timezone
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 1066               NaN
# 1067               NaN
# 1068               NaN
# 1069               NaN
# 1070               NaN
#
# [1071 rows x 5 columns]

# %%
task['Location'] = task.City + ", " + task.Country
task
# Out:
#                       Country              City  \
# 0         Antigua and Barbuda           Osbourn
# 1                   Argentina      Buenos Aires
# 2                       Aruba        Oranjestad
# 3                   Australia          Brisbane
# 4                   Australia            Cairns
# ...                       ...               ...
# 1066  United States (Wyoming)            Casper
# 1067  United States (Wyoming)              Cody
# 1068  United States (Wyoming)      Jackson Hole
# 1069                Venezuela           Caracas
# 1070                  Vietnam  Ho Chi Minh City
#
#                                      Airport name Airport code (IATA)  \
# 0                V. C. Bird International Airport                 ANU
# 1        Ministro Pistarini International Airport                 EZE
# 2             Queen Beatrix International Airport                 AUA
# 3                                Brisbane Airport                 BNE
# 4                                  Cairns Airport                 CNS
# ...                                           ...                 ...
# 1066  Casper-Natrona County International Airport                 CPR
# 1067                 Yellowstone Regional Airport                 COD
# 1068                         Jackson Hole Airport                 JAC
# 1069          Simon Bolivar International Airport                 CCS
# 1070           Tan Son Nhat International Airport                 SGN
#
#       Airport timezone                               Location
# 0                  NaN           Osbourn, Antigua and Barbuda
# 1                  NaN                Buenos Aires, Argentina
# 2                  NaN                      Oranjestad, Aruba
# 3                  NaN                    Brisbane, Australia
# 4                  NaN                      Cairns, Australia
# ...                ...                                    ...
# 1066               NaN        Casper, United States (Wyoming)
# 1067               NaN          Cody, United States (Wyoming)
# 1068               NaN  Jackson Hole, United States (Wyoming)
# 1069               NaN                     Caracas, Venezuela
# 1070               NaN              Ho Chi Minh City, Vietnam
#
# [1071 rows x 6 columns]

# %%
#task = task.head(10)

# %%
locations = task['Location'].unique()
lat = dict(zip(locations, pd.Series(locations).apply(lambda x: geolocator.geocode(x).latitude if geolocator.geocode(x) != None else 'Not Found')))
long = dict(zip(locations, pd.Series(locations).apply(lambda x: geolocator.geocode(x).longitude if geolocator.geocode(x) != None else 'Not Found')))

# %%
task['latitude'] = task['Location'].map(lat)
task['longitude'] = task['Location'].map(long)

# %%
notask = task[(task.longitude == 'Not Found') | (task.latitude == 'Not Found')]
notask['Airport timezone'] = 'Not Found'
notask
# Out:
# C:\Users\shahn\AppData\Local\Temp\ipykernel_8848\734169028.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   notask['Airport timezone'] = 'Not Found'
#                           Country                           City  \
# 184       United States (Florida)                Panama City, FL
# 225        United States (Nevada)                 Manchester, NH
# 252   United States (Puerto Rico)                       San Juan
# 399                        Greece                Preveza/Lefkada
# 624      United States (Colorado)           Telluride (Montrose)
# 633       United States (Florida)                    Panama City
# 685   United States (Puerto Rico)                       San Juan
# 697         United States (Texas)  Harlingen/ South Padre Island
# 888    United States (California)                   San Jose, CA
# 908       United States (Florida)                Panama City, FL
# 911       United States (Florida)             St. Petersburg, FL
# 1016  United States (Puerto Rico)                       San Juan
# 1017  United States (Puerto Rico)                       San Juan
#
#                                          Airport name Airport code (IATA)  \
# 184   Northwest Florida Beaches International Airport                 ECP
# 225                Manchester-Boston Regional Airport                 MHT
# 252            Luis Muñoz Marín International Airport                 SJU
# 399                           Aktion National Airport                 PVK
# 624                         Montrose Regional Airport                 MTJ
# 633   Northwest Florida Beaches International Airport                 ECP
# 685            Luis Muñoz Marín International Airport                 SJU
# 697                      Valley International Airport                 HRL
# 888   Norman Y. Mineta San Jose International Airport                 SJC
# 908   Northwest Florida Beaches International Airport                 ECP
# 911         St. Pete–Clearwater International Airport                 PIE
# 1016                              Isla Grande Airport                 SIG
# 1017           Luis Muñoz Marín International Airport                 SJU
#
#      Airport timezone                                           Location  \
# 184         Not Found           Panama City, FL, United States (Florida)
# 225         Not Found             Manchester, NH, United States (Nevada)
# 252         Not Found              San Juan, United States (Puerto Rico)
# 399         Not Found                            Preveza/Lefkada, Greece
# 624         Not Found     Telluride (Montrose), United States (Colorado)
# 633         Not Found               Panama City, United States (Florida)
# 685         Not Found              San Juan, United States (Puerto Rico)
# 697         Not Found  Harlingen/ South Padre Island, United States (...
# 888         Not Found           San Jose, CA, United States (California)
# 908         Not Found           Panama City, FL, United States (Florida)
# 911         Not Found        St. Petersburg, FL, United States (Florida)
# 1016        Not Found              San Juan, United States (Puerto Rico)
# 1017        Not Found              San Juan, United States (Puerto Rico)
#
#        latitude  longitude
# 184   Not Found  Not Found
# 225   Not Found  Not Found
# 252   Not Found  Not Found
# 399   Not Found  Not Found
# 624   Not Found  Not Found
# 633   Not Found  Not Found
# 685   Not Found  Not Found
# 697   Not Found  Not Found
# 888   Not Found  Not Found
# 908   Not Found  Not Found
# 911   Not Found  Not Found
# 1016  Not Found  Not Found
# 1017  Not Found  Not Found

# %%
donetask = task[(task.longitude != 'Not Found') & (task.latitude != 'Not Found')]
donetask['Airport timezone'] = donetask.apply(lambda x: my_func(lng=x['longitude'], lat=x['latitude']),axis=1)
donetask
# Out:
# C:\Users\shahn\AppData\Local\Temp\ipykernel_8848\852828504.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   donetask['Airport timezone'] = donetask.apply(lambda x: my_func(lng=x['longitude'], lat=x['latitude']),axis=1)
#                       Country              City  \
# 0         Antigua and Barbuda           Osbourn
# 1                   Argentina      Buenos Aires
# 2                       Aruba        Oranjestad
# 3                   Australia          Brisbane
# 4                   Australia            Cairns
# ...                       ...               ...
# 1066  United States (Wyoming)            Casper
# 1067  United States (Wyoming)              Cody
# 1068  United States (Wyoming)      Jackson Hole
# 1069                Venezuela           Caracas
# 1070                  Vietnam  Ho Chi Minh City
#
#                                      Airport name Airport code (IATA)  \
# 0                V. C. Bird International Airport                 ANU
# 1        Ministro Pistarini International Airport                 EZE
# 2             Queen Beatrix International Airport                 AUA
# 3                                Brisbane Airport                 BNE
# 4                                  Cairns Airport                 CNS
# ...                                           ...                 ...
# 1066  Casper-Natrona County International Airport                 CPR
# 1067                 Yellowstone Regional Airport                 COD
# 1068                         Jackson Hole Airport                 JAC
# 1069          Simon Bolivar International Airport                 CCS
# 1070           Tan Son Nhat International Airport                 SGN
#
#                     Airport timezone                               Location  \
# 0                    America/Antigua           Osbourn, Antigua and Barbuda
# 1     America/Argentina/Buenos_Aires                Buenos Aires, Argentina
# 2                      America/Aruba                      Oranjestad, Aruba
# 3                 Australia/Brisbane                    Brisbane, Australia
# 4                 Australia/Brisbane                      Cairns, Australia
# ...                              ...                                    ...
# 1066                  America/Denver        Casper, United States (Wyoming)
# 1067                  America/Denver          Cody, United States (Wyoming)
# 1068                  America/Denver  Jackson Hole, United States (Wyoming)
# 1069                 America/Caracas                     Caracas, Venezuela
# 1070                Asia/Ho_Chi_Minh              Ho Chi Minh City, Vietnam
#
#        latitude   longitude
# 0     17.141418  -61.797359
# 1    -34.607568  -58.437089
# 2     12.526874  -70.035685
# 3    -27.468968  153.023499
# 4    -16.920666  145.772185
# ...         ...         ...
# 1066  42.850119 -106.325138
# 1067  44.570448 -108.983362
# 1068  43.684017 -110.443663
# 1069  10.481317  -66.879606
# 1070  10.775844  106.701756
#
# [1058 rows x 8 columns]

# %%
result = pd.concat([donetask, notask])

# %%
result
# Out:
#                           Country                City  \
# 0             Antigua and Barbuda             Osbourn
# 1                       Argentina        Buenos Aires
# 2                           Aruba          Oranjestad
# 3                       Australia            Brisbane
# 4                       Australia              Cairns
# ...                           ...                 ...
# 888    United States (California)        San Jose, CA
# 908       United States (Florida)     Panama City, FL
# 911       United States (Florida)  St. Petersburg, FL
# 1016  United States (Puerto Rico)            San Juan
# 1017  United States (Puerto Rico)            San Juan
#
#                                          Airport name Airport code (IATA)  \
# 0                    V. C. Bird International Airport                 ANU
# 1            Ministro Pistarini International Airport                 EZE
# 2                 Queen Beatrix International Airport                 AUA
# 3                                    Brisbane Airport                 BNE
# 4                                      Cairns Airport                 CNS
# ...                                               ...                 ...
# 888   Norman Y. Mineta San Jose International Airport                 SJC
# 908   Northwest Florida Beaches International Airport                 ECP
# 911         St. Pete–Clearwater International Airport                 PIE
# 1016                              Isla Grande Airport                 SIG
# 1017           Luis Muñoz Marín International Airport                 SJU
#
#                     Airport timezone  \
# 0                    America/Antigua
# 1     America/Argentina/Buenos_Aires
# 2                      America/Aruba
# 3                 Australia/Brisbane
# 4                 Australia/Brisbane
# ...                              ...
# 888                        Not Found
# 908                        Not Found
# 911                        Not Found
# 1016                       Not Found
# 1017                       Not Found
#
#                                          Location   latitude   longitude
# 0                    Osbourn, Antigua and Barbuda  17.141418  -61.797359
# 1                         Buenos Aires, Argentina -34.607568  -58.437089
# 2                               Oranjestad, Aruba  12.526874  -70.035685
# 3                             Brisbane, Australia -27.468968  153.023499
# 4                               Cairns, Australia -16.920666  145.772185
# ...                                           ...        ...         ...
# 888      San Jose, CA, United States (California)  Not Found   Not Found
# 908      Panama City, FL, United States (Florida)  Not Found   Not Found
# 911   St. Petersburg, FL, United States (Florida)  Not Found   Not Found
# 1016        San Juan, United States (Puerto Rico)  Not Found   Not Found
# 1017        San Juan, United States (Puerto Rico)  Not Found   Not Found
#
# [1071 rows x 8 columns]

# %%
result[['Country', 'City', 'Airport name', 'Airport code (IATA)',
       'Airport timezone']].to_excel('Task_Complete.xlsx',index = False)
